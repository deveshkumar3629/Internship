# %%
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get('https://meesho.com/bags-ladies/pl/p7vbp')

# %%
soup=BeautifulSoup(page.content)

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><link rel="preconnect" href="https://static-assets.meesho.com"/><link rel="dns-prefetch" href="https://static-assets.meesho.com"/><link rel="preload" as="font" type="font/woff2" crossorigin="true" href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap"/><link href="https://static-assets.meesho.com/css/mier-fonts.css?display=swap" rel="stylesheet"/><title>Buy Ladies Bag Online at Lowest Prices | Meesho</title><meta name="description" content="Get the latest collection of stylish ladies bags at affordable prices online at Meesho. We have a wide range of trendy designs of bags like sling, clutch, etc."/><meta property="keywords" content="meesho,reseller,products,reselling"/><meta property="og:title" content="Buy Ladies Bag Online at Lowest Prices | Meesho"/><meta property="og:description" content="Get the latest collection of stylish ladies bags at affordable prices online at Meesho. We have a wide range of trendy designs of bags like sling, clutch, etc."/><meta property="og:type" content="website"/><meta property="twitter:creator" content="Meesho"/><meta property="twitter:title" content="Buy Ladies Bag Online at Lowest Prices | Meesho"/><meta property="twitter:description" content="Get the latest collection of stylish ladies bags at affordable prices online at Meesho. We have a wide range of trendy designs of bags like sling, clutch, etc."/><meta name="google-site-verification" content="hN0QXvUaNeMlD8XXGkR9z5vDDiSrPQJ8ioMDa7eAMEU"/><meta property="twitter:card" content="summary"/><script type="application/ld+json">{\n            "@context": "https://schema.org",\n            "@type": "Organization",\n            "url": "https://www.meesho.com",\n            "logo": "https://images.meesho.com/images/marketing/1641634588603.png",\n            "name": "Meesho",\n            "contactPoint": [{\n              "@type": "ContactPoint",\n              "telephone": "080-68878782",\n              "contactType": "customer service"\n            }],\n            "sameAs": [\n              "https://twitter.com/Meesho_Official",\n              "https://www.facebook.com/meeshosupply",\n              "https://www.instagram.com/meeshoapp",\n              "https://www.youtube.com/channel/UCaGHIRKYUYlaI_ZAt2hxpjw",\n              "https://www.linkedin.com/company/meesho"\n            ]\n          }</script><script type="application/ld+json" id="jsonLd">{&quot;@context&quot;:&quot;http://schema.org&quot;,&quot;@type&quot;:&quot;ItemList&quot;,&quot;itemListElement&quot;:[{&quot;@type&quot;:&quot;ListItem&quot;,&quot;position&quot;:1,&quot;url&quot;:&quot;https://meesho.com/graceful-fancy-women-handbags/p/1cx3e1&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/82165609/cleq8_512.jpg&quot;],&quot;name&quot;:&quot;Graceful Fancy Women Handbags&quot;},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;position&quot;:2,&quot;url&quot;:&quot;https://meesho.com/graceful-fancy-women-handbags/p/1hk4b0&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/89958348/vyamw_512.jpg&quot;],&quot;name&quot;:&quot;Graceful Fancy Women Handbags&quot;},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;position&quot;:3,&quot;url&quot;:&quot;https://meesho.com/graceful-classy-women-handbags/p/1idttn&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/91344443/tmv9d_512.jpg&quot;],&quot;name&quot;:&quot;Graceful Classy Women Handbags&quot;},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;position&quot;:4,&quot;url&quot;:&quot;https://meesho.com/handbags/p/157yit&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/69235589/kzuba_512.jpg&quot;],&quot;name&quot;:&quot;handbags&quot;},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;position&quot;:5,&quot;url&quot;:&quot;https://meesho.com/gorgeous-classy-women-handbags/p/1iejda&quot;,&quot;image&quot;:[&quot;https://images.meesho.com/images/products/91377550/bjkng_512.jpg&quot;],&quot;name&quot;:&quo ...

# %% [markdown]
# ### Scraping product names

# %%
prod_name=[]
for i in soup.find_all('div',class_="Card__BaseCard-sc-b3n78k-0 cXRroa NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 eEBPAI NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 eEBPAI"):
    prod_name.append(i.text)
    
prod_name
# Out:
# ['Graceful Fancy Women Handbags₹262₹36228% off₹100 discount on 1st orderFree Delivery',
#  'Graceful Fancy Women Handbags₹291₹39126% off₹100 discount on 1st orderFree Delivery3.7Supplier',
#  'Graceful Classy Women Handbags₹560₹66015% off₹100 discount on 1st orderFree Delivery3.9Supplier',
#  'handbags₹220₹31330% off₹93 discount on 1st orderFree Delivery3.7Supplier',
#  'Gorgeous Classy Women Handbags₹738₹83812% off₹100 discount on 1st orderFree Delivery3.8Supplier',
#  'Gorgeous Classy Women Handbags₹384₹48421% off₹100 discount on 1st orderFree Delivery3.6Supplier',
#  'Graceful Fancy Women Handbags₹106₹15130% off₹45 discount on 1st orderDelivery ₹85',
#  'Voguish Classy Women Handbags₹664₹76413% off₹100 discount on 1st orderFree Delivery4.8Supplier',
#  'Classic Fashionable Women Handbags₹529₹62916% off₹100 discount on 1st orderFree Delivery3.2Supplier',
#  'Handbags for Women and Girls with 2 Main compartments₹350₹45022% off₹100 discount on 1st orderFree Delivery3.8Supplier',
#  'Elegant Stylish Women Handbags₹378₹47821% off₹100 discount on 1st orderFree Delivery3.6Supplier',
#  'Gorgeous Fancy Women Handbags₹378₹47821% off₹100 discount on 1st orderFree Delivery3.6Supplier',
#  'Elegant Classy Women Handbags₹245₹34529% off₹100 discount on 1st orderFree Delivery3.5Supplier',
#  'Elegant Classy Women Handbags₹384₹48421% off₹100 discount on 1st orderFree Delivery3.6Supplier',
#  'Graceful Alluring Women Handbags₹384₹48421% off₹100 discount on 1st orderFree Delivery3.6Supplier',
#  'Ravishing Fancy Women Handbags₹334₹43423% off₹100 discount on 1st orderFree Delivery3.9Supplier',
#  'Classic Fancy Women Handbags₹207₹29530% off₹88 discount on 1st orderFree Delivery3.9Supplier',
#  'Voguish Attractive Women Handbags₹383₹48321% off₹100 discount on 1st orderFree Delivery3.7Supplier',
#  'Trendy Fashionable Women Handbags ₹658₹75813% off₹100 discount on 1st orderDelivery ₹854.5Supplier',
#  'Classic Versatile Women Handbags₹198₹28230% off₹84 discount on 1st orderFree Delivery']

# %% [markdown]
# ### scraping prices

# %%
prices=[]
for i in soup.find_all('div',class_="Card__BaseCard-sc-b3n78k-0 fVRkfg NewProductCard__PriceRow-sc-j0e7tu-5 dYYUrF NewProductCard__PriceRow-sc-j0e7tu-5 dYYUrF"):
    prices.append(i.text)
    
prices
# Out:
# ['₹262₹36228% off',
#  '₹291₹39126% off',
#  '₹560₹66015% off',
#  '₹220₹31330% off',
#  '₹738₹83812% off',
#  '₹384₹48421% off',
#  '₹106₹15130% off',
#  '₹664₹76413% off',
#  '₹529₹62916% off',
#  '₹350₹45022% off',
#  '₹378₹47821% off',
#  '₹378₹47821% off',
#  '₹245₹34529% off',
#  '₹384₹48421% off',
#  '₹384₹48421% off',
#  '₹334₹43423% off',
#  '₹207₹29530% off',
#  '₹383₹48321% off',
#  '₹658₹75813% off',
#  '₹198₹28230% off']

# %% [markdown]
# ### scraping discounts

# %%
disc=[]
for i in soup.find_all('span',class_="Text__StyledText-sc-oo0kvp-0 cZvGTZ"):
    disc.append(i.text)
    
disc
# Out:
# ['28% off',
#  '26% off',
#  '15% off',
#  '30% off',
#  '12% off',
#  '21% off',
#  '30% off',
#  '13% off',
#  '16% off',
#  '22% off',
#  '21% off',
#  '21% off',
#  '29% off',
#  '21% off',
#  '21% off',
#  '23% off',
#  '30% off',
#  '21% off',
#  '13% off',
#  '30% off']
